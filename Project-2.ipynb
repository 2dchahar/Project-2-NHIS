# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_1.csv')
print("Original Data:")
print(df.head())
rows, columns = df.shape
print(f"The dataset contains {rows} rows and {columns} columns.")
print('=============================================')
print("Datatypes of each column:")
print(df.dtypes)
print('=============================================')
df['dteday'] = pd.to_datetime(df['dteday'], errors='coerce')
print(df.info())
print('=============================================')
print("Summary of Dataset:")
print(df.info())
print("Dataset Preview:")
print(df.head())
for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nUnique values in column '{column}':")
    print(unique_values)
print('=============================================')
df_cleaned = df_cleaned.drop_duplicates()
df_cleaned = df.dropna()
column_to_drop = "Unnamed: 0"
if column_to_drop in df_cleaned.columns:
    df_cleaned = df_cleaned.drop(columns=[column_to_drop])
output_file = "cleaned_dataset_1.csv"
df_cleaned.to_csv(output_file, index=False)
print(f"Cleaned data has been saved to {output_file}.")
# Out:
# Original Data:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24
# The dataset contains 610 rows and 10 columns.
# ...
# Datatypes of each column:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# dtype: object
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
# ...

# %%
df = pd.read_csv('cleaned_dataset_1.csv')
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  2011-01-01       1   0     1   0    False        6           1
# 1          2  2011-01-01       1   0     1   1    False        6           1
# 2          3  2011-01-01       1   0     1   2    False        6           1
# 3          4  2011-01-01       1   0     1   3    False        6           1
# 4          5  2011-01-01       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 272      273  2011-12-01       1   0     1  19    False        3           1
# 273      274  2011-12-01       1   0     1  20    False        3           1
# 274      275  2011-12-01       1   0     1  21    False        3           1
# 275      276  2011-12-01       1   0     1  22    False        3           1
# 276      277  2011-12-01       1   0     1  23    False        3           1
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df = pd.read_csv('dataset_2.csv')
print("Original Data:")
print(df.head())
rows, columns = df.shape
print(f"The dataset contains {rows} rows and {columns} columns.")
print('=============================================')
print("Datatypes of each column:")
print(df.dtypes)
print('=============================================')
print("Summary of Dataset:")
print(df.info())
print("Dataset Preview:")
print(df.head())
for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nUnique values in column '{column}':")
    print(unique_values)
print('=============================================')
df_cleaned = df_cleaned.drop_duplicates()
df_cleaned = df.dropna()
column_to_drop = "Unnamed: 0"
if column_to_drop in df_cleaned.columns:
    df_cleaned = df_cleaned.drop(columns=[column_to_drop])
output_file = "cleaned_dataset_2.csv"
df_cleaned.to_csv(output_file, index=False)
print(f"Cleaned data has been saved to {output_file}.")
# Out:
# Original Data:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered   cnt
# 0         0.0      1.0  0.2879  0.81        0.0     3.0        13.0  16.0
# 1         1.0      2.0  0.2727  0.80        0.0     8.0        32.0  40.0
# 2         2.0      3.0  0.2727  0.80        0.0     5.0        27.0  32.0
# 3         3.0      4.0  0.2879  0.75        0.0     3.0        10.0  13.0
# 4         4.0      5.0  0.2879  0.75        0.0     0.0         1.0   1.0
# The dataset contains 999 rows and 8 columns.
# ...
# Datatypes of each column:
# Unnamed: 0    float64
# instant       float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual        float64
# registered    float64
# cnt           float64
# dtype: object
# ...
# Summary of Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
# ...

# %%
df = pd.read_csv('cleaned_dataset_2.csv')
df
# Out:
#      instant   atemp   hum  windspeed  casual  registered   cnt
# 0        1.0  0.2879  0.81     0.0000     3.0        13.0  16.0
# 1        2.0  0.2727  0.80     0.0000     8.0        32.0  40.0
# 2        3.0  0.2727  0.80     0.0000     5.0        27.0  32.0
# 3        4.0  0.2879  0.75     0.0000     3.0        10.0  13.0
# 4        5.0  0.2879  0.75     0.0000     0.0         1.0   1.0
# ..       ...     ...   ...        ...     ...         ...   ...
# 594    606.0  0.2121  0.93     0.1045     0.0        30.0  30.0
# 595    607.0  0.2121  0.93     0.1045     1.0        28.0  29.0
# 596    608.0  0.2121  0.93     0.1045     0.0        31.0  31.0
# 597    609.0  0.2727  0.80     0.0000     2.0        36.0  38.0
# 598    610.0  0.2576  0.86     0.0000     1.0        40.0  41.0
#
# [599 rows x 7 columns]

# %%
df = pd.read_csv('dataset_3.csv')
print("Original Data:")
print(df.head())
rows, columns = df.shape
print(f"The dataset contains {rows} rows and {columns} columns.")
print('=============================================')
print("Datatypes of each column:")
print(df.dtypes)
print('=============================================')
print("Summary of Dataset:")
print(df.info())
print("Dataset Preview:")
print(df.head())
for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nUnique values in column '{column}':")
    print(unique_values)
print('=============================================')
df_cleaned = df_cleaned.drop_duplicates()
df_cleaned = df.dropna()
column_to_drop = "Unnamed: 0"
if column_to_drop in df_cleaned.columns:
    df_cleaned = df_cleaned.drop(columns=[column_to_drop])
output_file = "cleaned_dataset_3.csv"
df_cleaned.to_csv(output_file, index=False)
print(f"Cleaned data has been saved to {output_file}.")
# Out:
# Original Data:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2
# The dataset contains 390 rows and 16 columns.
# ...
# Datatypes of each column:
# instant         int64
# dteday         object
# season          int64
# ...

# %%
df=pd.read_csv('cleaned_dataset_3.csv')
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df1 = pd.read_csv('cleaned_dataset_1.csv')
df2 = pd.read_csv('cleaned_dataset_2.csv')
merged_df = pd.merge(df1, df2, on='instant', how='inner')
merged_df.to_csv('merged_dataset_12.csv', index=False)

# %%
df = pd.read_csv('merged_dataset_12.csv')
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  2011-01-01       1   0     1   0    False        6           1
# 1          2  2011-01-01       1   0     1   1    False        6           1
# 2          3  2011-01-01       1   0     1   2    False        6           1
# 3          4  2011-01-01       1   0     1   3    False        6           1
# 4          5  2011-01-01       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 261      273  2011-12-01       1   0     1  19    False        3           1
# 262      274  2011-12-01       1   0     1  20    False        3           1
# 263      275  2011-12-01       1   0     1  21    False        3           1
# 264      276  2011-12-01       1   0     1  22    False        3           1
# 265      277  2011-12-01       1   0     1  23    False        3           1
#
# ...

# %%
df1 = pd.read_csv('merged_dataset_12.csv')
df2 = pd.read_csv('cleaned_dataset_3.csv')
merged_df = pd.concat([df1, df2], ignore_index=True)
print("Merged DataFrame:")
print(merged_df.head())
output_file = "merged_dataset_123.csv"
merged_df.to_csv(output_file, index=False)

print(f"The files have been successfully merged into {output_file}.")
# Out:
# Merged DataFrame:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  2011-01-01       1   0     1   0    False        6           1
# 1        2  2011-01-01       1   0     1   1    False        6           1
# 2        3  2011-01-01       1   0     1   2    False        6           1
# 3        4  2011-01-01       1   0     1   3    False        6           1
# 4        5  2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered   cnt
# 0  0.24  0.2879  0.81        0.0     3.0        13.0  16.0
# 1  0.22  0.2727  0.80        0.0     8.0        32.0  40.0
# 2  0.22  0.2727  0.80        0.0     5.0        27.0  32.0
# 3  0.24  0.2879  0.75        0.0     3.0        10.0  13.0
# 4  0.24  0.2879  0.75        0.0     0.0         1.0   1.0
# The files have been successfully merged into merged_dataset_123.csv.

# %%
df = pd.read_csv('merged_dataset_123.csv')
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  2011-01-01       1   0     1   0    False        6           1
# 1          2  2011-01-01       1   0     1   1    False        6           1
# 2          3  2011-01-01       1   0     1   2    False        6           1
# 3          4  2011-01-01       1   0     1   3    False        6           1
# 4          5  2011-01-01       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 651      615  28-01-2011       1   0     1  20    False        5           2
# 652      616  28-01-2011       1   0     1  21    False        5           2
# 653      617  28-01-2011       1   0     1  22    False        5           1
# 654      618  28-01-2011       1   0     1  23    False        5           1
# 655      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df = pd.read_csv('cleaned_dataset_1.csv')
x_column = "dteday"
y_column = "temp"
if x_column in df.columns and y_column in df.columns:
    plt.figure(figsize=(10, 6))
    plt.bar(df[x_column], df[y_column], color='skyblue')
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f"Bar Chart of {y_column} vs {x_column}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"Make sure the columns '{x_column}' and '{y_column}' exist in the dataset.")

# %%
df = pd.read_csv('cleaned_dataset_2.csv')
x_column = "cnt"
y_column = "hum"
if x_column in df.columns and y_column in df.columns:
    plt.figure(figsize=(10, 6))
    plt.bar(df[x_column], df[y_column], color='skyblue')
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f"Bar Chart of {y_column} vs {x_column}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"Make sure the columns '{x_column}' and '{y_column}' exist in the dataset.")

# %%
df = pd.read_csv('cleaned_dataset_3.csv')
x_column = "dteday"
y_column = "temp"
if x_column in df.columns and y_column in df.columns:
    plt.figure(figsize=(10, 6))
    plt.bar(df[x_column], df[y_column], color='skyblue')
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f"Bar Chart of {y_column} vs {x_column}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"Make sure the columns '{x_column}' and '{y_column}' exist in the dataset.")

# %%
df = pd.read_csv('cleaned_dataset_3.csv')
x_column = "dteday"
y_column = "atemp"
if x_column in df.columns and y_column in df.columns:
    plt.figure(figsize=(10, 6))
    plt.bar(df[x_column], df[y_column], color='skyblue')
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f"Bar Chart of {y_column} vs {x_column}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"Make sure the columns '{x_column}' and '{y_column}' exist in the dataset.")

# %%
df = pd.read_csv('cleaned_dataset_3.csv')
x_column = "dteday"
y_column = "hum"
if x_column in df.columns and y_column in df.columns:
    plt.figure(figsize=(10, 6))
    plt.bar(df[x_column], df[y_column], color='skyblue')
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f"Bar Chart of {y_column} vs {x_column}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"Make sure the columns '{x_column}' and '{y_column}' exist in the dataset.")

# %%
df = pd.read_csv('merged_dataset_12.csv')
print(df.head())
heatmap_data = df.select_dtypes(include=["number"])
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data.corr(), annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Heatmap of Correlation Matrix", fontsize=16)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  2011-01-01       1   0     1   0    False        6           1
# 1        2  2011-01-01       1   0     1   1    False        6           1
# 2        3  2011-01-01       1   0     1   2    False        6           1
# 3        4  2011-01-01       1   0     1   3    False        6           1
# 4        5  2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered   cnt
# 0  0.24  0.2879  0.81        0.0     3.0        13.0  16.0
# 1  0.22  0.2727  0.80        0.0     8.0        32.0  40.0
# 2  0.22  0.2727  0.80        0.0     5.0        27.0  32.0
# 3  0.24  0.2879  0.75        0.0     3.0        10.0  13.0
# 4  0.24  0.2879  0.75        0.0     0.0         1.0   1.0

# %%
df = pd.read_csv('merged_dataset_123.csv')
print(df.head())
heatmap_data = df.select_dtypes(include=["number"])
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data.corr(), annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Heatmap of Correlation Matrix", fontsize=16)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  2011-01-01       1   0     1   0    False        6           1
# 1        2  2011-01-01       1   0     1   1    False        6           1
# 2        3  2011-01-01       1   0     1   2    False        6           1
# 3        4  2011-01-01       1   0     1   3    False        6           1
# 4        5  2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered   cnt
# 0  0.24  0.2879  0.81        0.0     3.0        13.0  16.0
# 1  0.22  0.2727  0.80        0.0     8.0        32.0  40.0
# 2  0.22  0.2727  0.80        0.0     5.0        27.0  32.0
# 3  0.24  0.2879  0.75        0.0     3.0        10.0  13.0
# 4  0.24  0.2879  0.75        0.0     0.0         1.0   1.0

# %%
df = pd.read_csv('cleaned_merged_dataset_123.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  2011-01-01       1   0     1   0    False        6           1
# 1        2  2011-01-01       1   0     1   1    False        6           1
# 2        3  2011-01-01       1   0     1   2    False        6           1
# 3        4  2011-01-01       1   0     1   3    False        6           1
# 4        5  2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered   cnt
# 0  0.24  0.2879  0.81        0.0     3.0        13.0  16.0
# 1  0.22  0.2727  0.80        0.0     8.0        32.0  40.0
# 2  0.22  0.2727  0.80        0.0     5.0        27.0  32.0
# 3  0.24  0.2879  0.75        0.0     3.0        10.0  13.0
# 4  0.24  0.2879  0.75        0.0     0.0         1.0   1.0

# %%
df = pd.read_csv("cleaned_merged_dataset_123.csv")
column = "temp"
plt.boxplot(df[column])
plt.title("Box Plot")
plt.show()

# %%
df = pd.read_csv("cleaned_merged_dataset_123.csv")
column = "atemp"
plt.boxplot(df[column])
plt.title("Box Plot")
plt.show()

# %%
df = pd.read_csv("cleaned_merged_dataset_123.csv")
column = "hum"
plt.boxplot(df[column])
plt.title("Box Plot")
plt.show()

# %%
df = pd.read_csv("cleaned_merged_dataset_123.csv")
column = "cnt"
plt.boxplot(df[column])
plt.title("Box Plot")
plt.show()

# %%
df = pd.read_csv("cleaned_merged_dataset_123.csv")
column = "windspeed"
plt.boxplot(df[column])
plt.title("Box Plot")
plt.show()

# %%
df = pd.read_csv("cleaned_merged_dataset_123.csv")
selected_columns = ["temp", "atemp", "hum", "cnt"]
existing_columns = [col for col in selected_columns if col in df.columns]
if existing_columns:
    print("Skewness of Selected Columns:")
    skewness = df[existing_columns].skew()
    print(skewness)

    print("\nCorrelation Matrix of Selected Columns:")
    correlation_matrix = df[existing_columns].corr()
    print(correlation_matrix)

    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
    plt.title("Correlation Matrix Heatmap (Selected Columns)")
    plt.show()
else:
    print("None of the selected columns exist in the dataset. Please check the column names.")
# Out:
# Skewness of Selected Columns:
# temp     0.882930
# atemp    0.694956
# hum      0.364209
# cnt      1.080000
# dtype: float64
#
# Correlation Matrix of Selected Columns:
#            temp     atemp       hum       cnt
# temp   1.000000  0.926084 -0.002674  0.216089
# atemp  0.926084  1.000000  0.155710  0.153378
# hum   -0.002674  0.155710  1.000000 -0.283004
# cnt    0.216089  0.153378 -0.283004  1.000000
